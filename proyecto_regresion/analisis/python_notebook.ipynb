# %%
#Importamos las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargamos los datos
house_price_regression= pd.read_excel('../data/regression_data.xls')
house_price_regression.head() #Mostramos los primeros 5 registros
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
#Eliminamos la columna 'date' ya que no la utilizaremos en el analisis
house_price_regression.drop('date', axis=1, inplace=True)
house_price_regression.head(10)
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
# 5  7237550310         4       4.50         5420    101930     1.0           0
# 6  1321400060         3       2.25         1715      6819     2.0           0
# 7  2008000270         3       1.50         1060      9711     1.0           0
# 8  2414600126         3       1.00         1780      7470     1.0           0
# 9  3793500160         3       2.50         1890      6560     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
#Mostramos la cantidad de filas 
print('Cantidad de filas: ', house_price_regression.shape[0])
# Out:
# Cantidad de filas:  21597

# %%
#VALORES UNICOS

#Columna 'bedrooms'
house_price_regression['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  8,  9, 11, 10, 33])

# %%
#Columna 'bathrooms'
house_price_regression['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 1.25, 5.25, 6.  , 0.5 , 5.5 ,
#        6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
#Columna 'floors'
house_price_regression['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
#Columna 'condition'
house_price_regression['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2])

# %%
#Columna 'grade'
house_price_regression['grade'].unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13])

# %%
#Ordenamos los datos en orden decreciente por el precio de la casa. 
house_price_regression.sort_values(by='price', ascending=False).head(10)['id'] #Mostramso los 10 ids de las casas mas caras
# Out:
# 7245    6762700020
# 3910    9808700762
# 9245    9208900037
# 4407    2470100110
# 1446    8907500070
# 1313    7558700030
# 1162    1247600105
# 8085    1924059029
# 2624    7738500731
# 8629    3835500195
# Name: id, dtype: int64

# %%
#Precio promedio de las casas
house_price_regression['price'].mean()
# Out:
# 540296.5735055795

# %%
#Utilizamos la funcion 'groupby' 
#Agrupamos los datos por la columna 'bedrooms' y calculamos el promedio de la columna 'price'
house_price_regression.groupby('bedrooms')['price'].mean()
# Out:
# bedrooms
# 1     3.182395e+05
# 2     4.013877e+05
# 3     4.662766e+05
# 4     6.355647e+05
# 5     7.868741e+05
# 6     8.258535e+05
# 7     9.514478e+05
# 8     1.105077e+06
# 9     8.939998e+05
# 10    8.200000e+05
# 11    5.200000e+05
# 33    6.400000e+05
# Name: price, dtype: float64

# %%
#Agrupamos los datos por la columna 'bedrooms' y calculamos el promedio de lacolumna 'sqft_living' 
house_price_regression.groupby('bedrooms')['sqft_living'].mean()
# Out:
# bedrooms
# 1      888.153061
# 2     1239.752899
# 3     1805.837235
# 4     2554.649666
# 5     3047.545284
# 6     3284.341912
# 7     3974.210526
# 8     3800.000000
# 9     3775.000000
# 10    3706.666667
# 11    3000.000000
# 33    1620.000000
# Name: sqft_living, dtype: float64

# %%
#Precio promedio de las casas con 'waterfront'
house_price_regression[house_price_regression['waterfront']==1]['price'].mean()
# Out:
# 1662524.1840490797

# %%
#Precio promedio de las casas sin 'waterfront'
house_price_regression[house_price_regression['waterfront']==0]['price'].mean()
# Out:
# 531762.32415788

# %%
#Observamos si existe alguna correlacion entre las variables 'condition' y 'grade' 
house_price_regression[['condition', 'grade']].corr()
# Out:
#            condition     grade
# condition   1.000000 -0.146896
# grade      -0.146896  1.000000

# %%
#plot to visually check if there is a positive correlation or negative correlation or no correlation between both variables
sns.regplot(x='condition', y='grade', data=house_price_regression)
# Out:
# <AxesSubplot:xlabel='condition', ylabel='grade'>

# %% [markdown]
# Observamos en la grafica que entre ambas variables ('condition' y 'grade') existe una correlación positiva, es decir, a mayor condición del inmueble, mayor será su calificación. Esto es lógico, ya que un inmueble en buenas condiciones tendrá una mejor calificación que uno en malas condiciones.

# %%
#CASAS POR CONDICIONES

#Cantidad de casas por condicion
house_price_regression['condition'].value_counts()
# Out:
# 3    14020
# 4     5677
# 5     1701
# 2      170
# 1       29
# Name: condition, dtype: int64

# %%
#Cantidad de casas por baños
house_price_regression['bathrooms'].value_counts()
# Out:
# 2.50    5377
# 1.00    3851
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1445
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      71
# 4.75      23
# 5.00      21
# 5.25      13
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 6.75       2
# 8.00       2
# 6.25       2
# 6.50       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
#Cantidad de casas por pisos
house_price_regression['floors'].value_counts()
# Out:
# 1.0    10673
# 2.0     8235
# 1.5     1910
# 3.0      611
# 2.5      161
# 3.5        7
# Name: floors, dtype: int64

# %%
#Cantidad de casas por calificacion
house_price_regression['grade'].value_counts()
# Out:
# 7     8974
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64

# %%
#Cantidad de casas por precio
house_price_regression['price'].value_counts()
# Out:
# 450000    172
# 350000    172
# 550000    159
# 500000    152
# 425000    150
#          ...
# 278800      1
# 439888      1
# 354901      1
# 942000      1
# 402101      1
# Name: price, Length: 3622, dtype: int64

# %%
#Un cliente nos pide que encontremos una casa con las siguientes categorias:

    #- 3 o 4 habitaciones
    #- Más de 3 baños
    #- 1 planta
    #- Que no tenga vistas al lago
    #- Tiene que tener por lo menos un 3 de condición
    #- La calificacion tiene que ser al menos de un 5
    #- El precio tiene que ser menos de 300000

#Creamos una variable que contenga los datos de las casas que cumplen con las condiciones
house_price_regression[((house_price_regression['bedrooms']==3) | (house_price_regression['bedrooms']==4)) & (house_price_regression['bathrooms']>3) & (house_price_regression['floors']==1) & (house_price_regression['waterfront']==0) & (house_price_regression['condition']>=3) & (house_price_regression['grade']>=5) & (house_price_regression['price']<300000)]
# Out:
# Empty DataFrame
# Columns: [id, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, price]
# Index: []

# %% [markdown]
# No hay ninguna casa que cumpla con las condicones que nos pide el cliente, por lo que no podemos recomendarle ninguna casa.

# %%
#Mostramos las casas que su precio es el doble de la media
house_price_regression[house_price_regression['price']>(house_price_regression['price'].mean()*2)]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420    101930     1.0
# 21     2524049179         3       2.75         3050     44867     1.0
# 49      822039084         3       2.50         2753     65005     1.0
# 69     1802000060         5       2.25         3200     20158     1.0
# 91     5036300431         5       2.75         3520      6353     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21560  9253900271         5       4.50         4850     10584     2.0
# 21574  7430200100         4       3.50         4910      9444     1.5
# 21577  8672200110         5       3.75         4170      8142     2.0
# 21581   191100405         4       3.25         3410     10125     2.0
# 21584   249000205         5       3.75         4470      8088     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
#Observamos cual es la diferencia entre el precio medio de las casas con 3 habitaciones y las casas con 4 habitaciones
house_price_regression[house_price_regression['bedrooms']==4]['price'].mean() - house_price_regression[house_price_regression['bedrooms']==3]['price'].mean()
# Out:
# 169288.0862289045

# %%
#Mostramos los distintos codigos postales
house_price_regression['zipcode'].unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039])

# %%
#Mostramos las casas que han sido renovadas
house_price_regression[house_price_regression['yr_renovated']>0]
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1      6414100192         3       2.25         2570      7242     2.0
# 35     9547205180         3       2.50         2300      3060     1.5
# 95     1483300570         4       2.50         3300     10250     1.0
# 103    2450000295         3       2.50         2920      8113     2.0
# 115    3626039325         3       3.50         4380      6350     2.0
# ...           ...       ...        ...          ...       ...     ...
# 19606  7351200295         3       1.75         1760      6788     2.0
# 20041   126039256         3       2.00         1520      5040     2.0
# 20428  4305600360         4       2.50         2400      9612     1.0
# 20431  3319500628         3       1.50         1010      1546     2.0
# 20946  1278000210         2       1.00          828      4524     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
 #Mostramos los detalles de la 11º casa mas cara de nuestro dataset
house_price_regression.sort_values(by='price', ascending=False).head(11).iloc[10]
# Out:
# id               6.065300e+09
# bedrooms         5.000000e+00
# bathrooms        6.000000e+00
# sqft_living      7.440000e+03
# sqft_lot         2.154000e+04
# floors           2.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        3.000000e+00
# grade            1.200000e+01
# sqft_above       5.550000e+03
# sqft_basement    1.890000e+03
# yr_built         2.003000e+03
# yr_renovated     0.000000e+00
# zipcode          9.800600e+04
# lat              4.756920e+01
# long            -1.221890e+02
# sqft_living15    4.740000e+03
# sqft_lot15       1.932900e+04
# price            4.210000e+06
# Name: 12358, dtype: float64
